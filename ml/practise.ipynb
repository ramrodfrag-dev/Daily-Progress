# %% [markdown]
# ### Code for getting images from the google drive

# %%
# Image 2: image stored in your Google Drive.
# First place the image in Google Drive, then update this path.
from google.colab import drive

drive.mount("/content/drive")
image2_path = "/content/drive/MyDrive/my_image.jpg"

image2 = cv2.imread(image2_path)
if image2 is None:
    raise FileNotFoundError(
        f"Could not read {image2_path}. Check the Google Drive path and filename."
    )

print("Image 2: image from Google Drive")
cv2_imshow(image2)
