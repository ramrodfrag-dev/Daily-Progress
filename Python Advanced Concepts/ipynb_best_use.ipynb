# %% [markdown]
# ### Helper Functions

# %%
![Title](img/image_file_name_here.png)  #This is for the image pasting in ipynb

#    <img src="reference_pics/trees.jpg" alt="Forest" width="400" height="250">  # this also works in markdown
# Out:
# '[Title]' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ![Forest](reference_pics\trees.jpg)

# %% [markdown]
# <img src="reference_pics/trees.jpg" alt="Forest" width="400" height="250">
